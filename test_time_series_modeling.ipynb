# %%
import statsmodels.datasets.co2 as co2
co2_data = co2.load().data
print(co2_data)
# Out:
#               co2
# 1958-03-29  316.1
# 1958-04-05  317.3
# 1958-04-12  317.6
# 1958-04-19  317.5
# 1958-04-26  316.4
# ...           ...
# 2001-12-01  370.3
# 2001-12-08  370.8
# 2001-12-15  371.2
# 2001-12-22  371.3
# 2001-12-29  371.5
#
# [2284 rows x 1 columns]

# %%
co2_data = co2_data.fillna(co2_data.interpolate())

# %%
co2_data.plot()
# Out:
# <Axes: >

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(co2_data)
result.plot()

# %%
result.
# Out:
# 1958-03-29    316.1
# 1958-04-05    317.3
# 1958-04-12    317.6
# 1958-04-19    317.5
# 1958-04-26    316.4
#               ...
# 2001-12-01    370.3
# 2001-12-08    370.8
# 2001-12-15    371.2
# 2001-12-22    371.3
# 2001-12-29    371.5
# Freq: W-SAT, Length: 2284, dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(co2_data)

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(co2_data)
# Out:
# C:\Users\tosea\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.tsa.stattools import adfuller
adf, pval, usedlag, nobs, crit_vals, icbest =  adfuller(co2_data.co2.values)
print('ADF test statistic:', adf)
print('ADF p-values:', pval)
print('ADF number of lags used:', usedlag)
print('ADF number of observations:', nobs)
print('ADF critical values:', crit_vals)
print('ADF best information criterion:', icbest)
# Out:
# ADF test statistic: 0.033784597458261456
# ADF p-values: 0.9612384528286104
# ADF number of lags used: 27
# ADF number of observations: 2256
# ADF critical values: {'1%': -3.4332519309441296, '5%': -2.8628219967376647, '10%': -2.567452466810334}
# ADF best information criterion: 2578.3909092525305

# %%
prev_co2_value = co2_data.co2.shift()
differenced_co2 = co2_data.co2 - prev_co2_value
differenced_co2.plot()
# Out:
# <Axes: >

# %%
adf, pval, usedlag, nobs, crit_vals, icbest =  adfuller(differenced_co2.dropna())
print('ADF test statistic:', adf)
print('ADF p-values:', pval)
print('ADF number of lags used:', usedlag)
print('ADF number of observations:', nobs)
print('ADF critical values:', crit_vals)
print('ADF best information criterion:', icbest)
# Out:
# ADF test statistic: -15.727522408375822
# ADF p-values: 1.3013480157811357e-28
# ADF number of lags used: 27
# ADF number of observations: 2255
# ADF critical values: {'1%': -3.4332532193008443, '5%': -2.862822565622804, '10%': -2.5674527697012306}
# ADF best information criterion: 2556.2779733634547

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\tosea\Downloads\ICPSR_38430-V1\ICPSR_38430\DS0001\38430-0001-Data.tsv", sep='\t')
# Out:
# C:\Users\tosea\AppData\Local\Temp\ipykernel_25968\4084213612.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\tosea\Downloads\ICPSR_38430-V1\ICPSR_38430\DS0001\38430-0001-Data.tsv", sep='\t')
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25968\4084213612.py in <module>
# ----> 1 df = pd.read_csv(r"C:\Users\tosea\Downloads\ICPSR_38430-V1\ICPSR_38430\DS0001\38430-0001-Data.tsv", sep='\t')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ...

# %%
df2 = pd.read_csv(r"C:\Users\tosea\Downloads\ICPSR_38430-V1\ICPSR_38430\DS0002\38430-0002-Data.tsv", sep='\t')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25968\1208540040.py in <module>
# ----> 1 df2 = pd.read_csv(r"C:\Users\tosea\Downloads\ICPSR_38430-V1\ICPSR_38430\DS0002\38430-0002-Data.tsv", sep='\t')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df3 = pd.read_csv(r"C:\Users\tosea\Downloads\ICPSR_38430-V1\ICPSR_38430\DS0003\38430-0003-Data.tsv", sep='\t')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25968\3154639482.py in <module>
# ----> 1 df3 = pd.read_csv(r"C:\Users\tosea\Downloads\ICPSR_38430-V1\ICPSR_38430\DS0003\38430-0003-Data.tsv", sep='\t')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
